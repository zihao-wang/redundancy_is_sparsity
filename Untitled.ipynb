# %%
import GEOparse
gds = GEOparse.get_GEO(filepath="data/GDS4761_full.soft.gz")
# Out:
# 29-Aug-2022 00:26:18 INFO GEOparse - Parsing data/GDS4761_full.soft.gz:
# 29-Aug-2022 00:26:18 DEBUG GEOparse - DATABASE: Geo
# 29-Aug-2022 00:26:18 DEBUG GEOparse - DATASET: GDS4761
# 29-Aug-2022 00:26:18 DEBUG GEOparse - SUBSET: GDS4761_1
# 29-Aug-2022 00:26:18 DEBUG GEOparse - SUBSET: GDS4761_2
# 29-Aug-2022 00:26:18 DEBUG GEOparse - SUBSET: GDS4761_3
# 29-Aug-2022 00:26:18 DEBUG GEOparse - SUBSET: GDS4761_4
# 29-Aug-2022 00:26:18 DEBUG GEOparse - SUBSET: GDS4761_5
# 29-Aug-2022 00:26:18 DEBUG GEOparse - SUBSET: GDS4761_6
# 29-Aug-2022 00:26:18 DEBUG GEOparse - SUBSET: GDS4761_7
# 29-Aug-2022 00:26:18 DEBUG GEOparse - ANNOTATION:
# 29-Aug-2022 00:26:18 ERROR GEOparse - Cannot recognize type Annotation
# 29-Aug-2022 00:26:18 DEBUG GEOparse - DATASET: GDS4761

# %%
gds.metadata
# Out:
# {'title': ['Breast cancer metastases from different anatomical sites: fine-needle aspiration biopsies'],
#  'description': ['Analysis of breast cancer (BC) metastases from different anatomical sites collected prior to treatment.  The anatomical location of the metastatic lesion is associated with length of survival post-recurrence. Results provide insight into molecular mechanisms underlying BC site-specific metastases.'],
#  'type': ['Expression profiling by array'],
#  'pubmed_id': ['24287398'],
#  'platform': ['GPL10379'],
#  'platform_organism': ['Homo sapiens'],
#  'platform_technology_type': ['in situ oligonucleotide'],
#  'feature_count': ['52378'],
#  'sample_organism': ['Homo sapiens'],
#  'sample_type': ['RNA'],
#  'channel_count': ['1'],
#  'sample_count': ['91'],
#  'value_type': ['transformed count'],
#  'reference_series': ['GSE46141'],
#  'order': ['none'],
#  'update_date': ['Aug 13 2014']}

# %%
gds.columns
# Out:
#                                                   description  \
# GSM1124891  Value for GSM1124891: KI_TEX_2957_156 ascites;...
# GSM1124888  Value for GSM1124888: KI_TEX_2924_119 bone; sr...
# GSM1124890  Value for GSM1124890: KI_TEX_2741_111 bone; sr...
# GSM1124904  Value for GSM1124904: KI_TEX_3005_154 bone; sr...
# GSM1124927  Value for GSM1124927: KI_TEX_503_41 bone; src:...
# ...                                                       ...
# GSM1124923  Value for GSM1124923: KI_TEX_3014_137 skin loc...
# GSM1124925  Value for GSM1124925: KI_TEX_2742_26 skin loca...
# GSM1124929  Value for GSM1124929: KI_TEX_1563_31 skin loca...
# GSM1124934  Value for GSM1124934: KI_TEX_1522_83 skin loca...
# GSM1124937  Value for GSM1124937: KI_TEX_2909_126 skin; sr...
#
#                         tissue
# GSM1124891  ascite  metastasis
# GSM1124888    bone  metastasis
# GSM1124890    bone  metastasis
# GSM1124904    bone  metastasis
# GSM1124927    bone  metastasis
# ...

# %%
gds.table
# Out:
#                       ID_REF                 IDENTIFIER  GSM1124891  \
# 0           100138926_TGI_at                    SLC16A1       12.70
# 1           100131045_TGI_at                   BX098869        4.03
# 2           100134882_TGI_at                       IFNG        7.98
# 3           100149534_TGI_at           100149534_TGI_at       12.40
# 4           100160054_TGI_at           100160054_TGI_at        6.90
# ...                      ...                        ...         ...
# 52373          merck2-HCV_at          RosettaGeneID:HCV         NaN
# 52374  merck2-HCV_revcomp_at  RosettaGeneID:HCV_revcomp         NaN
# 52375          merck2-HIV_at          RosettaGeneID:HIV         NaN
# 52376  merck2-HIV_revcomp_at  RosettaGeneID:HIV_revcomp         NaN
# 52377          merck2-flu_at          RosettaGeneID:flu         NaN
#
#        GSM1124888  GSM1124890  GSM1124904  GSM1124927  GSM1124953  GSM1124869  \
# ...

# %%
for k in gds.subsets:
    print(gds.subsets[k].metadata)
# Out:
# {'dataset_id': ['GDS4761'], 'description': ['ascite  metastasis'], 'sample_id': ['GSM1124891'], 'type': ['tissue']}
# {'dataset_id': ['GDS4761'], 'description': ['bone  metastasis'], 'sample_id': ['GSM1124927,GSM1124904,GSM1124953,GSM1124888,GSM1124890'], 'type': ['tissue']}
# {'dataset_id': ['GDS4761'], 'description': ['local metastasis in the breast'], 'sample_id': ['GSM1124933,GSM1124882,GSM1124910,GSM1124919,GSM1124898,GSM1124905,GSM1124932,GSM1124903,GSM1124869,GSM1124870,GSM1124884'], 'type': ['tissue']}
# {'dataset_id': ['GDS4761'], 'description': ['liver metastasis'], 'sample_id': ['GSM1124946,GSM1124868,GSM1124895,GSM1124944,GSM1124908,GSM1124867,GSM1124947,GSM1124951,GSM1124957,GSM1124921,GSM1124902,GSM1124878,GSM1124897,GSM1124945,GSM1124939,GSM1124952'], 'type': ['tissue']}
# {'dataset_id': ['GDS4761'], 'description': ['lung  metastasis'], 'sample_id': ['GSM1124914,GSM1124900'], 'type': ['tissue']}
# ...

# %%
gds.subsets['GDS4761_1'].metadata
# Out:
# {'dataset_id': ['GDS4761'],
#  'description': ['ascite  metastasis'],
#  'sample_id': ['GSM1124891'],
#  'type': ['tissue']}
